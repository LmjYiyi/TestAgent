# %%
response = {'input': '步骤一、(3+5)*4等于几?', 'output': '\n\n(3+5)*4 的计算步骤如下：\n\n1. 先计算括号内的加法：3 + 5 = 8\n2. 再将结果乘以 4：8 × 4 = 32\n\n最终结果是：32'} 

a = response["output"]

print(a)
# Out:
# (3+5)*4 的计算步骤如下：
#
# 1. 先计算括号内的加法：3 + 5 = 8
# 2. 再将结果乘以 4：8 × 4 = 32
#
# 最终结果是：32

# %%
a=['接口中文名: 订单查询, 场景名: 订单状态查询', '接口中文名: 用户注册, 场景名: 渠道推广注册', '接口中文名: 用户注册, 场景名: 第三方登录注册', '接口中文名: 用户注册, 场景名: 后台批量导入注册', '接口中文名: 用户注册, 场景名: 普通用户注册', '接口中文名: 订单查询, 场景名: 普通订单查询', '接口中文名: 订单查询, 场景名: 日期范围查询', '接口中文名: 订单查询, 场景名: 分页查询']
b=a[0]
print(b)
c = dict(pair.split(": ") for pair in b.split(", "))
print(c)
d = c['接口中文名']
print(d)
# Out:
# 接口中文名: 订单查询, 场景名: 订单状态查询
# {'接口中文名': '订单查询', '场景名': '订单状态查询'}
# 订单查询
